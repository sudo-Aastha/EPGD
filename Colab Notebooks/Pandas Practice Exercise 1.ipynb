# %% [markdown]
# #### Introduction
#
# The air quality data for this segment has been divided into three different csv files.
#
# `info.csv` has the data hour by hour data about the concentration of polutants in the air and the status of the intruments.
# `item_info` has the data for items and levels of concetration.
# `station_info` has the data for measuring stations.
#
# Read in all the three datasets and then print the first five rows.
#
# You can download the dataset from kaggle website: https://www.kaggle.com/bappekim/air-pollution-in-seoul

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/sample_data/Measurement_info.csv")
data.head()
# Out:
#    Measurement date  Station code  Item code  Average value  Instrument status
# 0  2017-01-01 00:00         101.0        1.0          0.004                0.0
# 1  2017-01-01 00:00         101.0        3.0          0.059                0.0
# 2  2017-01-01 00:00         101.0        5.0          1.200                0.0
# 3  2017-01-01 00:00         101.0        6.0          0.002                0.0
# 4  2017-01-01 00:00         101.0        8.0         73.000                0.0

# %%
item = pd.read_csv("/content/sample_data/Measurement_item_info.csv")
item.head()
# Out:
#    Item code Item name Unit of measurement  Good(Blue)  Normal(Green)  \
# 0          1       SO2                 ppm        0.02           0.05
# 1          3       NO2                 ppm        0.03           0.06
# 2          5        CO                 ppm        2.00           9.00
# 3          6        O3                 ppm        0.03           0.09
# 4          8      PM10       Mircrogram/m3       30.00          80.00
#
#    Bad(Yellow)  Very bad(Red)
# 0         0.15            1.0
# 1         0.20            2.0
# 2        15.00           50.0
# 3         0.15            0.5
# 4       150.00          600.0

# %%
station = pd.read_csv("/content/sample_data/Measurement_station_info.csv")
station.head()
# Out:
#    Station code Station name(district)  \
# 0           101              Jongno-gu
# 1           102                Jung-gu
# 2           103             Yongsan-gu
# 3           104           Eunpyeong-gu
# 4           105           Seodaemun-gu
#
#                                              Address   Latitude   Longitude
# 0  19, Jong-ro 35ga-gil, Jongno-gu, Seoul, Republ...  37.572016  127.005008
# 1  15, Deoksugung-gil, Jung-gu, Seoul, Republic o...  37.564263  126.974676
# 2  136, Hannam-daero, Yongsan-gu, Seoul, Republic...  37.540033  127.004850
# 3  215, Jinheung-ro, Eunpyeong-gu, Seoul, Republi...  37.609823  126.934848
# 4  32, Segeomjeong-ro 4-gil, Seodaemun-gu, Seoul,...  37.593742  126.949679

# %% [markdown]
# #### Question 1
#
# Create a new Dataframe whcih has information about the item code and item name

# %%
sub_item = item[['Item code', 'Item name']]
display(sub_item.head())
# Out:
#    Item code Item name
# 0          1       SO2
# 1          3       NO2
# 2          5        CO
# 3          6        O3
# 4          8      PM10

# %% [markdown]
# #### Question 2
#
# Create a new Dataframe whcih has information about the station code and station name

# %%
sub_station = station[['Station code', 'Station name(district)']]
display(sub_station.head())
# Out:
#    Station code Station name(district)
# 0           101              Jongno-gu
# 1           102                Jung-gu
# 2           103             Yongsan-gu
# 3           104           Eunpyeong-gu
# 4           105           Seodaemun-gu

# %% [markdown]
# ### Question 3
#
# In the `data` DataFrame add in a column displaying the names of the items.

# %%
data_i = data.copy()
data_i = pd.merge(data_i, sub_item, on='Item code', how='left')
display(data_i.head())
# Out:
#    Measurement date  Station code  Item code  Average value  \
# 0  2017-01-01 00:00         101.0        1.0          0.004
# 1  2017-01-01 00:00         101.0        3.0          0.059
# 2  2017-01-01 00:00         101.0        5.0          1.200
# 3  2017-01-01 00:00         101.0        6.0          0.002
# 4  2017-01-01 00:00         101.0        8.0         73.000
#
#    Instrument status Item name
# 0                0.0       SO2
# 1                0.0       NO2
# 2                0.0        CO
# 3                0.0        O3
# 4                0.0      PM10

# %% [markdown]
# ### Question 4
#
# In the `data_i` DataFrame add in a column displaying the names of the stations.

# %%
data_s = pd.merge(data_i, sub_station, on='Station code', how='left')
display(data_s.head())
# Out:
#    Measurement date  Station code  Item code  Average value  \
# 0  2017-01-01 00:00         101.0        1.0          0.004
# 1  2017-01-01 00:00         101.0        3.0          0.059
# 2  2017-01-01 00:00         101.0        5.0          1.200
# 3  2017-01-01 00:00         101.0        6.0          0.002
# 4  2017-01-01 00:00         101.0        8.0         73.000
#
#    Instrument status Item name Station name(district)
# 0                0.0       SO2              Jongno-gu
# 1                0.0       NO2              Jongno-gu
# 2                0.0        CO              Jongno-gu
# 3                0.0        O3              Jongno-gu
# 4                0.0      PM10              Jongno-gu

# %% [markdown]
# ### Question 5
#
# In the `data_s` DataFrame drop the columns `Station code` and `Item code`. As these columns have not become redundant. You can find the relevant function in the pandas library [here](https://pandas.pydata.org/docs/reference/index.html).

# %%
data_s = data_s.drop(columns=['Station code', 'Item code'])
display(data_s.head())
# Out:
#    Measurement date  Average value  Instrument status Item name  \
# 0  2017-01-01 00:00          0.004                0.0       SO2
# 1  2017-01-01 00:00          0.059                0.0       NO2
# 2  2017-01-01 00:00          1.200                0.0        CO
# 3  2017-01-01 00:00          0.002                0.0        O3
# 4  2017-01-01 00:00         73.000                0.0      PM10
#
#   Station name(district)
# 0              Jongno-gu
# 1              Jongno-gu
# 2              Jongno-gu
# 3              Jongno-gu
# 4              Jongno-gu

# %% [markdown]
# ### Question 6
#
# Given below are the meanings of the values in the `Instrument status`.
#
# - 0: Normal
# - 1: Need for calibration
# - 2: Abnormal
# - 4: Power cut off
# - 8: Under repair
# - 9: Abnormal data
#
# Using the information given above, add a column in the `data` DataFrame to give the status of the intsruments. Then drop the `Instrument status` column.
#
# Hint: First create a dictionary from the data, then use the same dictionary to create a DataFrame and then merge the DataFrame. with `data`

# %%
status_dict = {
    0: 'Normal',
    1: 'Need for calibration',
    2: 'Abnormal',
    4: 'Power cut off',
    8: 'Under repair',
    9: 'Abnormal data'
}
status_map_df = pd.DataFrame(list(status_dict.items()), columns=['Instrument status', 'Instrument status description'])
display(status_map_df.head())
# Out:
#    Instrument status Instrument status description
# 0                  0                        Normal
# 1                  1          Need for calibration
# 2                  2                      Abnormal
# 3                  4                 Power cut off
# 4                  8                  Under repair

# %%
data = pd.merge(data, status_map_df, on='Instrument status', how='left')
display(data.head())
# Out:
#    Measurement date  Station code  Item code  Average value  \
# 0  2017-01-01 00:00         101.0        1.0          0.004
# 1  2017-01-01 00:00         101.0        3.0          0.059
# 2  2017-01-01 00:00         101.0        5.0          1.200
# 3  2017-01-01 00:00         101.0        6.0          0.002
# 4  2017-01-01 00:00         101.0        8.0         73.000
#
#    Instrument status Instrument status description
# 0                0.0                        Normal
# 1                0.0                        Normal
# 2                0.0                        Normal
# 3                0.0                        Normal
# 4                0.0                        Normal

# %%
data = data.drop(columns=['Instrument status'])
display(data.head())
# Out:
#    Measurement date  Station code  Item code  Average value  \
# 0  2017-01-01 00:00         101.0        1.0          0.004
# 1  2017-01-01 00:00         101.0        3.0          0.059
# 2  2017-01-01 00:00         101.0        5.0          1.200
# 3  2017-01-01 00:00         101.0        6.0          0.002
# 4  2017-01-01 00:00         101.0        8.0         73.000
#
#   Instrument status description
# 0                        Normal
# 1                        Normal
# 2                        Normal
# 3                        Normal
# 4                        Normal

# %%
data =

# %% [markdown]
# ### Question 7
#
# Extract the time series data, that is year, month, date and hour form the `Measurement date` column. Once all the data is extrcted drop the `Measurement date` column.
#
# This operation might take some time as the dataset we are working with is very large.

# %%
data['Measurement date'] = pd.to_datetime(data['Measurement date'], format='mixed', errors='coerce')
data['Year'] = data['Measurement date'].dt.year
data['Month'] = data['Measurement date'].dt.month
data['Date'] = data['Measurement date'].dt.day
data['Hour'] = data['Measurement date'].dt.hour
data = data.drop(columns=['Measurement date'])
data.head()
# Out:
#    Station code  Item code  Average value Instrument status description  \
# 0         101.0        1.0          0.004                        Normal
# 1         101.0        3.0          0.059                        Normal
# 2         101.0        5.0          1.200                        Normal
# 3         101.0        6.0          0.002                        Normal
# 4         101.0        8.0         73.000                        Normal
#
#      Year  Month  Date  Hour
# 0  2017.0    1.0   1.0   0.0
# 1  2017.0    1.0   1.0   0.0
# 2  2017.0    1.0   1.0   0.0
# 3  2017.0    1.0   1.0   0.0
# 4  2017.0    1.0   1.0   0.0

# %%
processed_data = processed_data.drop(columns=['Measurement date'])
display(processed_data.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_4154/3237675171.py in <cell line: 0>()
# ----> 1 processed_data = processed_data.drop(columns=['Measurement date'])
#       2 display(processed_data.head())
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4828                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4829             else:
# -> 4830                 new_axis = axis.drop(labels, errors=errors)
#    4831             indexer = axis.get_indexer(new_axis)
#    4832
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    7068         if mask.any():
#    7069             if errors != "ignore":
# -> 7070                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071             indexer = indexer[~mask]
#    7072         return self.delete(indexer)
#
# KeyError: "['Measurement date'] not found in axis"

# %%
processed_data = pd.merge(data_s, status_map_df, on='Instrument status', how='left')
processed_data = processed_data.drop(columns=['Instrument status'])
display(processed_data.head())
# Out:
#    Measurement date  Average value Item name Station name(district)  \
# 0  2017-01-01 00:00          0.004       SO2              Jongno-gu
# 1  2017-01-01 00:00          0.059       NO2              Jongno-gu
# 2  2017-01-01 00:00          1.200        CO              Jongno-gu
# 3  2017-01-01 00:00          0.002        O3              Jongno-gu
# 4  2017-01-01 00:00         73.000      PM10              Jongno-gu
#
#   Instrument status description
# 0                        Normal
# 1                        Normal
# 2                        Normal
# 3                        Normal
# 4                        Normal
